# %% [markdown]
# # Multiple Regression

# %% [markdown]
# Multiple regression is a method which process one or more values as the input feature

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

# %%
data = fetch_california_housing(as_frame= True)

# %%
df = data.frame

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
df.shape
# Out:
# (20640, 9)

# %%
x = df.iloc[:, :-1]
x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
y = data.target
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64

# %% [markdown]
# # Stats model

# %% [markdown]
# stast model is a mathematical representation of  relationships between variales , used for understanding data, making predictions and testing hypothesis

# %%
import statsmodels.api as sm
import statsmodels.formula as smf

# %%
x_constatnt =  sm.add_constant(x)

# %%
pd.DataFrame(x_constatnt)
# Out:
#        const  MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0        1.0  8.3252      41.0  6.984127   1.023810       322.0  2.555556
# 1        1.0  8.3014      21.0  6.238137   0.971880      2401.0  2.109842
# 2        1.0  7.2574      52.0  8.288136   1.073446       496.0  2.802260
# 3        1.0  5.6431      52.0  5.817352   1.073059       558.0  2.547945
# 4        1.0  3.8462      52.0  6.281853   1.081081       565.0  2.181467
# ...      ...     ...       ...       ...        ...         ...       ...
# 20635    1.0  1.5603      25.0  5.045455   1.133333       845.0  2.560606
# 20636    1.0  2.5568      18.0  6.114035   1.315789       356.0  3.122807
# 20637    1.0  1.7000      17.0  5.205543   1.120092      1007.0  2.325635
# 20638    1.0  1.8672      18.0  5.329513   1.171920       741.0  2.123209
# 20639    1.0  2.3886      16.0  5.254717   1.162264      1387.0  2.616981
#
#        Latitude  Longitude
# 0         37.88    -122.23
# ...

# %%
dir(sm.OLS)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_kwargs',
#  '_fit_collinear',
#  '_fit_ridge',
#  '_fit_zeros',
#  '_formula_max_endog',
#  '_get_init_kwds',
#  '_handle_data',
#  '_kwargs_allowed',
#  '_setup_score_hess',
#  '_sqrt_lasso',
#  'df_model',
#  'df_resid',
#  'endog_names',
#  'exog_names',
#  'fit',
#  'fit_regularized',
#  'from_formula',
#  'get_distribution',
#  'hessian',
#  'hessian_factor',
#  'information',
#  'initialize',
#  'loglike',
#  'predict',
#  'score',
#  'whiten']

# %%
model = sm.OLS(y, x_constatnt).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            MedHouseVal   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.606
# Method:                 Least Squares   F-statistic:                     3970.
# Date:                Sat, 24 May 2025   Prob (F-statistic):               0.00
# Time:                        19:01:29   Log-Likelihood:                -22624.
# No. Observations:               20640   AIC:                         4.527e+04
# Df Residuals:                   20631   BIC:                         4.534e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -36.9419      0.659    -56.067      0.000     -38.233     -35.650
# ...

# %%
import matplotlib.pyplot as plt

# %%
print(len(x))
print(len(y))
# Out:
# 20640
# 20640

# %%
y_prd = model.predict(x_constatnt)

# %%
df.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'MedHouseVal'],
#       dtype='object')

# %% [markdown]
# # Statsmodel using formula

# %%
import statsmodels.formula.api as smf  # ✅ Correct
import statsmodels.formula.api as smf  # ✅ Correct


df['MedHouseVal'] = data.target


form_lr = smf.ols(
    formula='y ~ MedInc + HouseAge + AveRooms + AveBedrms + Population + AveOccup + Latitude + Longitude',
    data=df
).fit()


print(form_lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.606
# Method:                 Least Squares   F-statistic:                     3970.
# Date:                Sat, 24 May 2025   Prob (F-statistic):               0.00
# Time:                        19:01:30   Log-Likelihood:                -22624.
# No. Observations:               20640   AIC:                         4.527e+04
# Df Residuals:                   20631   BIC:                         4.534e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -36.9419      0.659    -56.067      0.000     -38.233     -35.650
# ...

# %% [markdown]
# # Correlation matrix

# %%
corr_mat = df.corr().round(2)

# %%
corr_mat
# Out:
#              MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc         1.00     -0.12      0.33      -0.06        0.00      0.02
# HouseAge      -0.12      1.00     -0.15      -0.08       -0.30      0.01
# AveRooms       0.33     -0.15      1.00       0.85       -0.07     -0.00
# AveBedrms     -0.06     -0.08      0.85       1.00       -0.07     -0.01
# Population     0.00     -0.30     -0.07      -0.07        1.00      0.07
# AveOccup       0.02      0.01     -0.00      -0.01        0.07      1.00
# Latitude      -0.08      0.01      0.11       0.07       -0.11      0.00
# Longitude     -0.02     -0.11     -0.03       0.01        0.10      0.00
# MedHouseVal    0.69      0.11      0.15      -0.05       -0.02     -0.02
#
#              Latitude  Longitude  MedHouseVal
# MedInc          -0.08      -0.02         0.69
# HouseAge         0.01      -0.11         0.11
# AveRooms         0.11      -0.03         0.15
# AveBedrms        0.07       0.01        -0.05
# ...

# %%
import  numpy as np
upper  =  corr_mat.where(np.triu(np.ones(corr_mat.shape) , k =1).astype(bool))
to_drop = [column for column in upper.columns if any(upper[column] > 0.60)]

# %%
df_reduced = df.drop(columns = to_drop )

# %%
df_reduced
# Out:
#        MedInc  HouseAge  AveRooms  Population  AveOccup  Latitude  Longitude
# 0      8.3252      41.0  6.984127       322.0  2.555556     37.88    -122.23
# 1      8.3014      21.0  6.238137      2401.0  2.109842     37.86    -122.22
# 2      7.2574      52.0  8.288136       496.0  2.802260     37.85    -122.24
# 3      5.6431      52.0  5.817352       558.0  2.547945     37.85    -122.25
# 4      3.8462      52.0  6.281853       565.0  2.181467     37.85    -122.25
# ...       ...       ...       ...         ...       ...       ...        ...
# 20635  1.5603      25.0  5.045455       845.0  2.560606     39.48    -121.09
# 20636  2.5568      18.0  6.114035       356.0  3.122807     39.49    -121.21
# 20637  1.7000      17.0  5.205543      1007.0  2.325635     39.43    -121.22
# 20638  1.8672      18.0  5.329513       741.0  2.123209     39.43    -121.32
# 20639  2.3886      16.0  5.254717      1387.0  2.616981     39.37    -121.24
#
# [20640 rows x 7 columns]

# %%
upper
# Out:
#              MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc          NaN     -0.12      0.33      -0.06        0.00      0.02
# HouseAge        NaN       NaN     -0.15      -0.08       -0.30      0.01
# AveRooms        NaN       NaN       NaN       0.85       -0.07     -0.00
# AveBedrms       NaN       NaN       NaN        NaN       -0.07     -0.01
# Population      NaN       NaN       NaN        NaN         NaN      0.07
# AveOccup        NaN       NaN       NaN        NaN         NaN       NaN
# Latitude        NaN       NaN       NaN        NaN         NaN       NaN
# Longitude       NaN       NaN       NaN        NaN         NaN       NaN
# MedHouseVal     NaN       NaN       NaN        NaN         NaN       NaN
#
#              Latitude  Longitude  MedHouseVal
# MedInc          -0.08      -0.02         0.69
# HouseAge         0.01      -0.11         0.11
# AveRooms         0.11      -0.03         0.15
# AveBedrms        0.07       0.01        -0.05
# ...

# %%
upper_filtered = upper.where(upper <= 0.60)
print(upper_filtered)
# Out:
#              MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc          NaN     -0.12      0.33      -0.06        0.00      0.02
# HouseAge        NaN       NaN     -0.15      -0.08       -0.30      0.01
# AveRooms        NaN       NaN       NaN        NaN       -0.07     -0.00
# AveBedrms       NaN       NaN       NaN        NaN       -0.07     -0.01
# Population      NaN       NaN       NaN        NaN         NaN      0.07
# AveOccup        NaN       NaN       NaN        NaN         NaN       NaN
# Latitude        NaN       NaN       NaN        NaN         NaN       NaN
# Longitude       NaN       NaN       NaN        NaN         NaN       NaN
# MedHouseVal     NaN       NaN       NaN        NaN         NaN       NaN
#
#              Latitude  Longitude  MedHouseVal
# MedInc          -0.08      -0.02          NaN
# HouseAge         0.01      -0.11         0.11
# AveRooms         0.11      -0.03         0.15
# AveBedrms        0.07       0.01        -0.05
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))

# %%
sns.heatmap(upper,  cmap= 'YlGnBu', annot= True)
# Out:
# <Axes: >

# %%
corr_mat = df.corr().round(4)

# %%
eigenvalues ,  eigenvectors = np.linalg.eig(df.corr())
pd.Series(eigenvalues).sort_values
# Out:
# <bound method Series.sort_values of 0    2.036667
# 1    1.975268
# 2    0.063704
# 3    0.043798
# 4    0.303498
# 5    1.611997
# 6    0.692167
# 7    1.269845
# 8    1.003056
# dtype: float64>

# %%
np.abs(pd.Series(eigenvectors[:, 8])).sort_values(ascending = False)
# Out:
# 5    0.972657
# 1    0.222486
# 3    0.052638
# 2    0.029585
# 6    0.022452
# 7    0.012079
# 4    0.009570
# 0    0.007112
# 8    0.000215
# dtype: float64
